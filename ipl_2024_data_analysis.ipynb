# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ipl_2024_deliveries.csv.zip')

# %%
df.head()
# Out:
#    match_id  season  match_no          date                            venue  \
# 0    202401    2024         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai
# 1    202401    2024         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai
# 2    202401    2024         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai
# 3    202401    2024         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai
# 4    202401    2024         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai
#
#   batting_team bowling_team  innings  over     striker  bowler  runs_of_bat  \
# 0          RCB          CSK        1   0.1       Kohli  Chahar            0
# 1          RCB          CSK        1   0.1       Kohli  Chahar            1
# 2          RCB          CSK        1   0.2  du Plessis  Chahar            0
# 3          RCB          CSK        1   0.3  du Plessis  Chahar            0
# 4          RCB          CSK        1   0.4  du Plessis  Chahar            0
#
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'match_no', 'date', 'venue', 'batting_team',
#        'bowling_team', 'innings', 'over', 'striker', 'bowler', 'runs_of_bat',
#        'extras', 'wide', 'legbyes', 'byes', 'noballs', 'wicket_type',
#        'player_dismissed', 'fielder'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# match_no              int64
# date                 object
# venue                object
# batting_team         object
# bowling_team         object
# innings               int64
# over                float64
# striker              object
# bowler               object
# runs_of_bat           int64
# extras                int64
# wide                  int64
# legbyes               int64
# byes                  int64
# noballs               int64
# wicket_type          object
# player_dismissed     object
# fielder              object
# total_runs            int64
# match                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# match_id                0
# season                  0
# match_no                0
# date                    0
# venue                   0
# batting_team            0
# bowling_team            0
# innings                 0
# over                    0
# striker                 0
# bowler                  0
# runs_of_bat             0
# extras                  0
# wide                    0
# legbyes                 0
# byes                    0
# noballs                 0
# wicket_type         16170
# player_dismissed    16170
# fielder             16344
# dtype: int64

# %%
df.tail()
# Out:
#        match_id  season  match_no          date  \
# 17048    202474    2024        74  May 26, 2024
# 17049    202474    2024        74  May 26, 2024
# 17050    202474    2024        74  May 26, 2024
# 17051    202474    2024        74  May 26, 2024
# 17052    202474    2024        74  May 26, 2024
#
#                                  venue batting_team bowling_team  innings  \
# 17048  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 17049  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 17050  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 17051  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 17052  MA Chidambaram Stadium, Chennai          KKR          SRH        2
#
#        over         striker         bowler  runs_of_bat  extras  wide  \
# 17048   9.5    Shreyas Iyer        Markram            1       0     0
# 17049   9.6  Venkatesh Iyer        Markram            1       0     0
# ...

# %%
df.drop(columns=['match_id','season'],inplace=True)

# %%
df.head(10)
# Out:
#    match_no          date                            venue batting_team  \
# 0         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 1         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 2         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 3         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 4         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 5         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 6         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 7         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 8         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 9         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
#
#   bowling_team  innings  over     striker            bowler  runs_of_bat  \
# 0          CSK        1   0.1       Kohli            Chahar            0
# ...

# %%
df.groupby('bowling_team')['extras'].sum().sort_values()
# Out:
# bowling_team
# GT       73
# LSG     114
# CSK     120
# PBKS    127
# KKR     131
# RR      131
# SRH     139
# DC      141
# MI      143
# RCB     145
# Name: extras, dtype: int64

# %%
df.groupby('batting_team')['extras'].sum().sort_values()
# Out:
# batting_team
# DC      104
# GT      104
# RR      106
# PBKS    109
# CSK     117
# LSG     124
# RCB     134
# SRH     141
# MI      145
# KKR     180
# Name: extras, dtype: int64

# %%
df['match']=df[['batting_team','bowling_team']].apply(lambda x: ':'.join(sorted(x)),axis=1)

# %%
df.head()
# Out:
#    match_no          date                            venue batting_team  \
# 0         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 1         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 2         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 3         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 4         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
#
#   bowling_team  innings  over     striker  bowler  runs_of_bat  extras  wide  \
# 0          CSK        1   0.1       Kohli  Chahar            0       1     1
# 1          CSK        1   0.1       Kohli  Chahar            1       0     0
# 2          CSK        1   0.2  du Plessis  Chahar            0       0     0
# 3          CSK        1   0.3  du Plessis  Chahar            0       0     0
# 4          CSK        1   0.4  du Plessis  Chahar            0       0     0
#
# ...

# %%
df['match_no'].max()
# Out:
# 74

# %%
df['venue'].unique()
# Out:
# array(['MA Chidambaram Stadium, Chennai',
#        'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur, Chandigarh',
#        'Eden Gardens, Kolkata', 'Sawai Mansingh Stadium, Jaipur',
#        'Narendra Modi Stadium, Ahmedabad',
#        'M.Chinnaswamy Stadium, Bengaluru',
#        'Rajiv Gandhi International Stadium, Hyderabad',
#        'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam',
#        'Wankhede Stadium, Mumbai', 'Arun Jaitley Stadium, Delhi',
#        'Himachal Pradesh Cricket Association Stadium, Dharamsala',
#        'Barsapara Cricket Stadium, Guwahati'], dtype=object)

# %%
df.head()
# Out:
#    match_no          date                            venue batting_team  \
# 0         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 1         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 2         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 3         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 4         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
#
#   bowling_team  innings  over     striker  bowler  runs_of_bat  extras  wide  \
# 0          CSK        1   0.1       Kohli  Chahar            0       1     1
# 1          CSK        1   0.1       Kohli  Chahar            1       0     0
# 2          CSK        1   0.2  du Plessis  Chahar            0       0     0
# 3          CSK        1   0.3  du Plessis  Chahar            0       0     0
# 4          CSK        1   0.4  du Plessis  Chahar            0       0     0
#
# ...

# %%
df.pivot_table(values='match_no',index='venue',aggfunc=pd.Series.nunique,fill_value=" ",margins=True)
# Out:
#                                                     match_no
# venue
# Arun Jaitley Stadium, Delhi                                5
# Barsapara Cricket Stadium, Guwahati                        1
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cr...         7
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...         2
# Eden Gardens, Kolkata                                      7
# Himachal Pradesh Cricket Association Stadium, D...         2
# M.Chinnaswamy Stadium, Bengaluru                           7
# MA Chidambaram Stadium, Chennai                            9
# Maharaja Yadavindra Singh International Cricket...         5
# Narendra Modi Stadium, Ahmedabad                           8
# Rajiv Gandhi International Stadium, Hyderabad              6
# Sawai Mansingh Stadium, Jaipur                             5
# Wankhede Stadium, Mumbai                                   7
# All                                                       71

# %%
df['match_no'].nunique()
# Out:
# 71

# %%
df.pivot_table(values='runs_of_bat',index='striker',aggfunc=sum,fill_value=" ").sort_values(by='runs_of_bat',ascending=False)
# Out:
#                    runs_of_bat
# striker
# Kohli                      741
# Gaikwad                    583
# Riyan Parag                573
# Head                       567
# Samson                     531
# ...                        ...
# Vaibhav Arora                1
# Maharaj                      1
# Washington Sundar            0
# Tushar Deshpande             0
# Mayank Dagar                 0
#
# [170 rows x 1 columns]

# %%
df.pivot_table(values='wicket_type',index='bowler',aggfunc='count',fill_value=" ").sort_values(by='wicket_type',ascending=False)
# Out:
#                   wicket_type
# bowler
# Harshal Patel              30
# Avesh Khan                 22
# Mukesh Kumar               22
# Chakaravarthy              21
# Bumrah                     21
# ...                       ...
# Suyash Sharma               0
# Manav Suthar                0
# Rishi Dhawan                0
# Lomror                      0
# Mukesh Choudhary            0
#
# [137 rows x 1 columns]

# %%
pd.pivot_table(df, values='total_runs', index=['match_no','venue', 'match','batting_team','bowling_team'], aggfunc=np.sum).sort_values(by='total_runs',ascending=False)
# Out:
#                                                                                                total_runs
# match_no venue                                              match   batting_team bowling_team
# 30       M.Chinnaswamy Stadium, Bengaluru                   RCB:SRH SRH          RCB                  299
# 16       Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta... DC:KKR  KKR          DC                   289
# 8        Rajiv Gandhi International Stadium, Hyderabad      MI:SRH  SRH          MI                   287
# 30       M.Chinnaswamy Stadium, Bengaluru                   RCB:SRH RCB          SRH                  272
# 35       Arun Jaitley Stadium, Delhi                        DC:SRH  SRH          DC                   271
# ...                                                                                                   ...
# 14       Wankhede Stadium, Mumbai                           MI:RR   MI           RR                   132
# ...

# %%
pd.pivot_table(df,values=['total_runs'],index=['venue','match_no',],columns=['batting_team'],aggfunc=np.sum,fill_value=" ")
# Out:
#                                      total_runs                              \
# batting_team                                CSK     DC     GT    KKR    LSG
# venue                       match_no
# Arun Jaitley Stadium, Delhi 35                   203.0
#                             40                   229.0  225.0
#                             43                   265.0
#                             56                   222.0
#                             64                   214.0                193.0
# ...                                         ...    ...    ...    ...    ...
# Wankhede Stadium, Mumbai    25
#                             29            214.0
#                             51                                 176.0
#                             55
#                             67                                        218.0
#
#
# batting_team                             MI PBKS    RCB     RR    SRH
# venue                       match_no
# ...

# %%
df[df['match_no']==74]
# Out:
#        match_no          date                            venue batting_team  \
# 16870        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16871        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16872        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16873        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16874        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# ...         ...           ...                              ...          ...
# 17048        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17049        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17050        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17051        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17052        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
#
# ...

# %%
pd.pivot_table(df[df['match_no']==74],values=['total_runs'],index=['venue','match_no',],columns=['batting_team'],aggfunc=np.sum,fill_value=" ")
# Out:
#                                          total_runs
# batting_team                                    KKR  SRH
# venue                           match_no
# MA Chidambaram Stadium, Chennai 74              121  120

# %%
pd.pivot_table(df[df['match_no']==74],values=['wicket_type'],index=['bowling_team','bowler'],aggfunc='count',fill_value=" ",observed=True)
# Out:
#                             wicket_type
# bowling_team bowler
# KKR          Chakaravarthy            1
#              Harshit Rana             2
#              Narine                   1
#              Russell                  3
#              Starc                    2
#              Vaibhav Arora            1
# SRH          Bhuvneshwar              0
#              Cummins                  1
#              Markram                  0
#              Shahbaz Ahmed            1
#              T Natarajan              0
#              Unadkat                  0

# %%
pd.pivot_table(df[df['match_no']==74],values=['runs_of_bat'],index=['batting_team','striker'],aggfunc=np.sum,fill_value=" ",observed=True)
# Out:
#                               runs_of_bat
# batting_team striker
# KKR          Gurbaz                    39
#              Narine                     6
#              Shreyas Iyer               6
#              Venkatesh Iyer            52
# SRH          Abdul Samad                4
#              Abhishek Sharma            2
#              Bhuvneshwar                0
#              Cummins                   24
#              Head                       0
#              Klaasen                   16
#              Markram                   20
#              Nitish Reddy              13
#              Shahbaz Ahmed              8
#              Tripathi                   9
#              Unadkat                    4

# %%
pd.pivot_table(df,values=['wicket_type'],index=['bowling_team','bowler'],aggfunc='count',fill_value=" ",observed=True)
# Out:
#                                 wicket_type
# bowling_team bowler
# CSK          Chahar                       5
#              Jadeja                       8
#              Mitchell                     1
#              Moeen Ali                    2
#              Mukesh Choudhary             0
# ...                                     ...
# SRH          T Natarajan                 20
#              Umran Malik                  0
#              Unadkat                      9
#              V Viyaskanth                 1
#              Washington Sundar            1
#
# [137 rows x 1 columns]

# %%
df.groupby(['bowling_team','bowler'])['wicket_type'].count()
# Out:
# bowling_team  bowler
# CSK           Chahar                5
#               Jadeja                8
#               Mitchell              1
#               Moeen Ali             2
#               Mukesh Choudhary      0
#                                    ..
# SRH           T Natarajan          20
#               Umran Malik           0
#               Unadkat               9
#               V Viyaskanth          1
#               Washington Sundar     1
# Name: wicket_type, Length: 137, dtype: int64

# %%
df.groupby('bowling_team').apply(lambda x:x.groupby('bowler')['wicket_type'].count().nlargest(1)).sort_values()
# Out:
# bowling_team  bowler
# LSG           Naveen-ul-Haq       15
# GT            Mohit Sharma        16
# RCB           Yash Dayal          16
# CSK           Tushar Deshpande    18
# SRH           T Natarajan         20
# KKR           Chakaravarthy       21
# MI            Bumrah              21
# DC            Mukesh Kumar        22
# RR            Avesh Khan          22
# PBKS          Harshal Patel       30
# Name: wicket_type, dtype: int64

# %%
df.groupby('batting_team').apply(lambda x:x.groupby('striker')['runs_of_bat'].sum().nlargest(1)).sort_values()
# Out:
# batting_team  striker
# PBKS          Shashank Singh    354
# MI            Rohit             417
# DC            Pant              446
# KKR           Narine            488
# LSG           Rahul             520
# GT            Sai Sudharsan     527
# SRH           Head              567
# RR            Riyan Parag       573
# CSK           Gaikwad           583
# RCB           Kohli             741
# Name: runs_of_bat, dtype: int64

# %%
df.head()
# Out:
#    match_no          date                            venue batting_team  \
# 0         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 1         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 2         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 3         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 4         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
#
#   bowling_team  innings  over     striker  bowler  runs_of_bat  extras  wide  \
# 0          CSK        1   0.1       Kohli  Chahar            0       1     1
# 1          CSK        1   0.1       Kohli  Chahar            1       0     0
# 2          CSK        1   0.2  du Plessis  Chahar            0       0     0
# 3          CSK        1   0.3  du Plessis  Chahar            0       0     0
# 4          CSK        1   0.4  du Plessis  Chahar            0       0     0
#
# ...

# %%
df2=pd.DataFrame(df[(df['wide']==0) & (df['noballs']==0)].groupby(['striker'])['runs_of_bat'].count()>50)

# %%
df2.index[df2.any(axis=1)]
# Out:
# Index(['Abdul Samad', 'Abhishek Sharma', 'Abishek Porel',
#        'Angkrish Raghuvanshi', 'Anuj Rawat', 'Arshad Khan', 'Ashutosh Sharma',
#        'Ashwin', 'Axar', 'Ayush Badoni', 'Bairstow', 'Brevis', 'Buttler',
#        'Cummins', 'Dhawan', 'Dhoni', 'Dhruv Jurel', 'Fraser-McGurk', 'Gaikwad',
#        'Green', 'Hardik Pandya', 'Harpreet Brar', 'Head', 'Hetmyer', 'Hooda',
#        'Ishan Kishan', 'Jadeja', 'Jaiswal', 'Jitesh Sharma', 'Karthik',
#        'Klaasen', 'Kohler-Cadmore', 'Kohli', 'Krunal Pandya', 'Livingstone',
#        'Lomror', 'Markram', 'Mayank', 'Miller', 'Mitchell', 'Moeen Ali',
#        'Naman Dhir', 'Narine', 'Nehal Wadhera', 'Nitish Reddy', 'Padikkal',
#        'Pant', 'Philip Salt', 'Pooran', 'Powell', 'Prabhsimran',
#        'Prithvi Shaw', 'Rahane', 'Rahul', 'Rahul Tewatia', 'Rajat Patidar',
#        'Ramandeep Singh', 'Rashid Khan', 'Ravindra', 'Rinku Singh',
#        'Riyan Parag', 'Rohit', 'Rossouw', 'Russell', 'Saha', 'Sai Sudharsan',
# ...

# %%
df[(df['wide']==0) & (df['noballs']==0)].groupby(['striker'])['runs_of_bat'].sum
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.generic.SeriesGroupBy object at 0x000001FDB2AE0ED0>>

# %%
filtered_df=df[(df['wide']==0) & (df['noballs']==0)]

# %%
batter_grouped=filtered_df.groupby('striker')

# %%
for i in batter_grouped:
    print(i)
# Out:
# ('Abdul Samad',        match_no          date                            venue batting_team  \
# 698           3  Mar 23, 2024            Eden Gardens, Kolkata          SRH
# 701           3  Mar 23, 2024            Eden Gardens, Kolkata          SRH
# 702           3  Mar 23, 2024            Eden Gardens, Kolkata          SRH
# 703           3  Mar 23, 2024            Eden Gardens, Kolkata          SRH
# 705           3  Mar 23, 2024            Eden Gardens, Kolkata          SRH
# ...         ...           ...                              ...          ...
# 16703        73  May 24, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16945        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16946        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16947        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
# 16950        74  May 26, 2024  MA Chidambaram Stadium, Chennai          SRH
#
# ...

# %%
results=batter_grouped['runs_of_bat'].agg('runs_of_bat'.count,sum('runs_of_bat'))
#results=results[results['count']>50]
print(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[362], line 1
# ----> 1 results=batter_grouped['runs_of_bat'].agg('runs_of_bat'.count,sum('runs_of_bat'))
#       2 #results=results[results['count']>50]
#       3 print(results)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
dfs=df[(df['wide']==0) & (df['noballs']==0)]

# %%
dfs2=dfs.pivot_table(values='runs_of_bat',index='striker',aggfunc='count')
dfs2
# Out:
#                  runs_of_bat
# striker
# Abdul Samad              108
# Abhinav Manohar           16
# Abhishek Sharma          235
# Abishek Porel            204
# Akash Deep                 2
# ...                      ...
# Williamson                27
# Wood                       3
# Yudhvir Singh             14
# de Kock                  186
# du Plessis               271
#
# [170 rows x 1 columns]

# %%
dfs2=dfs2[dfs2['runs_of_bat']>100]

# %%
dfs3=dfs.pivot_table(values='runs_of_bat',index='striker',aggfunc='sum')

# %%
dfs3=dfs3[dfs3['runs_of_bat']>100]

# %%
#dfs3.rename(columns={'runs_of_bat':'total'})
dfs2=dfs2.rename(columns={'runs_of_bat':'totalballsplayed'})

# %%
dfs3=dfs3.rename(columns={'runs_of_bat':'totalrunsscored'})

# %%
dffinal=dfs2.merge(dfs3,left_index=True,right_index=True)

# %%
dffinal
# Out:
#                       totalballsplayed  totalrunsscored
# striker
# Abdul Samad                        108              182
# Abhishek Sharma                    235              478
# Abishek Porel                      204              326
# Angkrish Raghuvanshi               105              163
# Ashutosh Sharma                    110              183
# ...                                ...              ...
# Venkatesh Iyer                     233              370
# Warner                             124              168
# Will Jacks                         130              224
# de Kock                            186              250
# du Plessis                         271              438
#
# [66 rows x 2 columns]

# %%
dffinal['strikerate']=(dffinal['totalrunsscored']/dffinal['totalballsplayed'])*100

# %%
dffinal.sort_values(by='strikerate',ascending=False).head(5)
# Out:
#                  totalballsplayed  totalrunsscored  strikerate
# striker
# Fraser-McGurk                 139              324  233.093525
# Abhishek Sharma               235              478  203.404255
# Head                          294              563  191.496599
# Tristan Stubbs                196              372  189.795918
# Karthik                       173              322  186.127168

# %%
dffinal.sort_values(by='totalrunsscored',ascending=False).head(5)
# Out:
#              totalballsplayed  totalrunsscored  strikerate
# striker
# Kohli                     479              741  154.697286
# Gaikwad                   412              579  140.533981
# Riyan Parag               383              573  149.608355
# Head                      294              563  191.496599
# Samson                    343              530  154.518950

# %%
dffinal.sort_values(by='strikerate').head(5)
# Out:
#             totalballsplayed  totalrunsscored  strikerate
# striker
# Saha                     115              136  118.260870
# Sam Curran               217              266  122.580645
# Rahane                   196              242  123.469388
# Dhawan                   121              152  125.619835
# Markram                  175              220  125.714286

# %%
df.tail()
# Out:
#        match_no          date                            venue batting_team  \
# 17048        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17049        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17050        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17051        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
# 17052        74  May 26, 2024  MA Chidambaram Stadium, Chennai          KKR
#
#       bowling_team  innings  over         striker         bowler  runs_of_bat  \
# 17048          SRH        2   9.5    Shreyas Iyer        Markram            1
# 17049          SRH        2   9.6  Venkatesh Iyer        Markram            1
# 17050          SRH        2  10.1  Venkatesh Iyer  Shahbaz Ahmed            1
# 17051          SRH        2  10.2    Shreyas Iyer  Shahbaz Ahmed            1
# 17052          SRH        2  10.3  Venkatesh Iyer  Shahbaz Ahmed            1
#
# ...

# %%
dfa3=df.pivot_table(values='total_runs',index='bowler',aggfunc='sum')

# %%
dfa2=df.pivot_table(values='wicket_type',index='bowler',aggfunc='count')

# %%
dfa=dfs.pivot_table(values='runs_of_bat',index='bowler',aggfunc='count')
dfa=dfa.rename({'runs_of_bat':"balldelivered"})

# %%
dfa
# Out:
#                  runs_of_bat
# bowler
# Abhishek Sharma           42
# Akash Deep                21
# Akash Madhwal            109
# Alzarri Joseph            58
# Anshul Kamboj             60
# ...                      ...
# Williams                  36
# Wood                      36
# Yash Dayal               302
# Yash Thakur              213
# Yudhvir Singh             24
#
# [137 rows x 1 columns]

# %%
dfacombined=dfa2.merge(dfa3,left_index=True,right_index=True)

# %%
dfafinal=dfacombined.merge(dfa,left_index=True,right_index=True)

# %%
dfafinal=dfafinal.rename(columns={"total_runs":"runs_given","runs_of_bat":"balldeliverd"})

# %%
dfafinal
# Out:
#                  wicket_type  runs_given  balldeliverd
# bowler
# Abhishek Sharma            2          51            42
# Akash Deep                 1          57            21
# Akash Madhwal              6         222           109
# Alzarri Joseph             1         131            58
# Anshul Kamboj              2         120            60
# ...                      ...         ...           ...
# Williams                   1          81            36
# Wood                       1          97            36
# Yash Dayal                16         496           302
# Yash Thakur               12         415           213
# Yudhvir Singh              1          52            24
#
# [137 rows x 3 columns]

# %%
dfafinal['economy_rate']=(dfafinal['runs_given']/dfafinal['balldeliverd'])*6

# %%
dfafinal['wicket_by_ball']=(dfafinal['balldeliverd']/dfafinal['wicket_type'])

# %%
dfafinal=dfafinal[dfafinal['balldeliverd']>50]

# %%
dfafinal
# Out:
#                    total_wicket  runs_given  balldeliverd  economy_rate  \
# bowler
# Akash Madhwal                 6         222           109     12.220183
# Alzarri Joseph                1         131            58     13.551724
# Anshul Kamboj                 2         120            60     12.000000
# Arshad Khan                   1         122            61     12.000000
# Arshdeep Singh               20         540           302     10.728477
# ...                         ...         ...           ...           ...
# Vijaykumar Vyshak             6         147            87     10.137931
# Warrier                       6         128            66     11.636364
# Will Jacks                    2         101            54     11.222222
# Yash Dayal                   16         496           302      9.854305
# Yash Thakur                  12         415           213     11.690141
#
#                    wicket_by_ball  wicket_by_run
# bowler
# ...

# %%
dfafinal['wicket_by_run']=(dfafinal['runs_given']/dfafinal['total_wicket'])

# %%
#dfafinal=dfafinal.rename(columns={'wicket_type':"total_wicket"})

# %%
dfafinal.sort_values(by='total_wicket',ascending=False).head()
# Out:
#                total_wicket  runs_given  balldeliverd  economy_rate  \
# bowler
# Harshal Patel            30         511           294     10.428571
# Mukesh Kumar             22         394           213     11.098592
# Avesh Khan               22         550           329     10.030395
# Chakaravarthy            21         424           300      8.480000
# Bumrah                   21         363           311      7.003215
#
#                wicket_by_ball  wicket_by_run
# bowler
# Harshal Patel        9.800000      17.033333
# Mukesh Kumar         9.681818      17.909091
# Avesh Khan          14.954545      25.000000
# Chakaravarthy       14.285714      20.190476
# Bumrah              14.809524      17.285714

# %%
dfafinal.sort_values(by='economy_rate').head()
# Out:
#              total_wicket  runs_given  balldeliverd  economy_rate  \
# bowler
# Narine                 18         385           330      7.000000
# Bumrah                 21         363           311      7.003215
# Santner                 3          64            54      7.111111
# Theekshana              2         149           120      7.450000
# Livingstone             3          90            72      7.500000
#
#              wicket_by_ball  wicket_by_run
# bowler
# Narine            18.333333      21.388889
# Bumrah            14.809524      17.285714
# Santner           18.000000      21.333333
# Theekshana        60.000000      74.500000
# Livingstone       24.000000      30.000000

# %%
df.head()
# Out:
#    match_no          date                            venue batting_team  \
# 0         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 1         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 2         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 3         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
# 4         1  Mar 22, 2024  MA Chidambaram Stadium, Chennai          RCB
#
#   bowling_team  innings  over     striker  bowler  runs_of_bat  extras  wide  \
# 0          CSK        1   0.1       Kohli  Chahar            0       1     1
# 1          CSK        1   0.1       Kohli  Chahar            1       0     0
# 2          CSK        1   0.2  du Plessis  Chahar            0       0     0
# 3          CSK        1   0.3  du Plessis  Chahar            0       0     0
# 4          CSK        1   0.4  du Plessis  Chahar            0       0     0
#
# ...
